# %%
import matplotlib.pyplot as plt

time = np.array([]);
for x in range(0, 5):
    time = np.append(time, x/2)
    
time = np.append(time, 3)
time = np.append(time, 4)
time = np.append(time, 4.5)

for x in range(5, 16):
    time = np.append(time, x)


values = np.array([23.25, 23.27, 23.28, 23.30, 23.30, 23.35, 23.44, 23.47, 23.47, 33.50, 33.55, 33.38, 33.12, 32.55, 32.20, 31.55, 31.26, 31.00, 30.75]);

y=0+23.47

# print(time)
# print(values)
plt.plot(time, values, 'o');
plt.axvline(x=5)

m, b = np.polyfit(time[9:], values[9:], 1)
plt.plot(time, m*time+b )


print(m * 5 + b)

plt.xlabel('Time (min)')
plt.ylabel('Temperature (degrees Celcius)')

plt.show()
# Out:
# 34.227999999999994

# %%
import numpy as np
import matplotlib.pyplot as plt

time = np.array([]);
for x in range(0,21):
    time = np.append(time, x * 30)
r1 = np.array([20.0, 20.5, 20.9, 21.4, 22.0, 22.3, 22.7,23,23.2,23.3,23.3,23.3,23.2,23.1,23.1,23.0,22.9,22.9,22.6,22.6,22.4])
plt.plot(time, r1, 'o');
plt.axvline(x=0)

m, b = np.polyfit(time[11:], r1[11:], 1)
plt.plot(time, m * time + b )


print( b)

plt.xlabel('Time (sec)')
plt.ylabel('Temperature (degrees Celcius)')

plt.show()
# Out:
# 24.366060606060614

# %%
r1 = np.array([19.0,19.8,20.9,21.4,22.0,22.3,22.7,23.0,23.2,23.3,23.3,23.3,23.2,23.1,23.1,23.0,22.9,22.8,22.6,22.6,22.4])


import numpy as np
import matplotlib.pyplot as plt

time = np.array([]);
for x in range(0,21):
    time = np.append(time, x * 30)
plt.plot(time, r1, 'o');
plt.axvline(x=0)

m, b = np.polyfit(time[11:], r1[11:], 1)
plt.plot(time, m * time + b )


print( b)

plt.xlabel('Time (sec)')
plt.ylabel('Temperature (degrees Celcius)')

plt.show()
# Out:
# 24.38424242424243

# %%
r1 = np.array([20.5,21.6,22.9,23.8, 25.1,26.7,27.9,28.3,28.4,28.4,28.3,28.3,28.2,28.1,28.0,28.0,27.9,27.8,27.8,27.7,27.6])
import numpy as np
import matplotlib.pyplot as plt

time = np.array([]);
for x in range(0,21):
    time = np.append(time, x * 30)
plt.plot(time, r1, 'o');
plt.axvline(x=0)

m, b = np.polyfit(time[11:], r1[11:], 1)
plt.plot(time, m * time + b )


print(b)

plt.xlabel('Time (sec)')
plt.ylabel('Temperature (degrees Celcius)')

plt.show()
# Out:
# 29.06727272727273
